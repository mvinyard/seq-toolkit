# %%
import seq_toolkit as seq

# %%
gene = seq.Gene()
gene.create(n_exons=8, return_gene=False)

# %%
gene.gene_df
# Out:
#     Start    End Feature  length
# 0       0    906     UTR     906
# 1     906   4578    exon    3672
# 2    5053   5456  intron     403
# 3    5456   8356    exon    2900
# 4    8356  12082  intron    3726
# 5   12082  12864    exon     782
# 6   12864  15427  intron    2563
# 7   15427  15560    exon     133
# 8   15560  16731  intron    1171
# 9   16731  17028    exon     297
# 10  17028  26268  intron    9240
# 11  26268  26373    exon     105
# 12  26373  36065  intron    9692
# 13  36065  36096    exon      31
# 14  36096  48023  intron   11927
# 15  48023  48188    exon     165
# 16  48188  50000     UTR    1812

# %%
gene.plot()
